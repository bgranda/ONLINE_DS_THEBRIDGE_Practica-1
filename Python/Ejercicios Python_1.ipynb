# %%
# Cálculo área de un paralelogramo (base x altura)
base = float(input("Introduce la base: "))
altura = float(input("Introduce la altura: "))
print(f"El área del paralelogramo es: {base * altura}")
# Out:
# Introduce la base:  4
# Introduce la altura:  5
# El área del paralelogramo es: 20.0

# %%
base = float(input("Introduce la base: "))
altura = float(input("Introduce la altura: "))
print(f"El área del paralelogramo es: {base * altura}")
# Out:
# Introduce la base:  4.0
# Introduce la altura:  5.0
# El área del paralelogramo es: 20.0

# %%
import math
replace (float, abs(float))
print(base)
print(altura)

print(f"El área del paralelogramo es: {base * altura}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import math
# ----> 2 replace (float, abs(float))
#       3 print(base)
#       4 print(altura)
#
# NameError: name 'replace' is not defined

# %%
import math

base = float(input("Introduce la base: "))
altura = float(input("Introduce la altura: ")

nueva_base = base.replace(float, abs(float))
nueva_altura = altura.replace(float, abs(float))

print(f"El área del paralelogramo es: {nueva_base * nueva_altura}"))
# Out:
#   Cell In[5], line 4
#     altura = float(input("Introduce la altura: ")
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import math

base = float(input("Introduce la base: "))
altura = float(input("Introduce la altura: "))

nueva_base = base.replace(float, abs(float))
nueva_altura = altura.replace(float, abs(float))

print(nueva_base)
print(nueva_altura)

print(f"El área del paralelogramo es: {nueva_base * nueva_altura}")
# Out:
# Introduce la base:  -5.5
# Introduce la altura:  3.5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 6
#       3 base = float(input("Introduce la base: "))
#       4 altura = float(input("Introduce la altura: "))
# ----> 6 nueva_base = base.replace(float, abs(float))
#       7 nueva_altura = altura.replace(float, abs(float))
#       9 print(nueva_base)
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
del base
del altura
del nueva_base
del nueva_altura
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 del base
#       2 del altura
# ----> 3 del nueva_base
#       4 del nueva_altura
#
# NameError: name 'nueva_base' is not defined

# %%
import math

nueva_base = abs(float)(input("Introduce la base: "))
nueva_altura = abs(float)(input("Introduce la altura: "))

print(f"El área del paralelogramo es: {nueva_base * nueva_altura}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import math
# ----> 3 nueva_base = abs(float)(input("Introduce la base: "))
#       4 nueva_altura = abs(float)(input("Introduce la altura: "))
#       6 print(f"El área del paralelogramo es: {nueva_base * nueva_altura}")
#
# TypeError: bad operand type for abs(): 'type'

# %%
del nueva_base
del nueva_altura
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 del nueva_base
#       2 del nueva_altura
#
# NameError: name 'nueva_base' is not defined

# %%
base = float(input("Introduce la base: "))
altura = float(input("Introduce la altura: "))

nueva_base = abs(base)
nueva_altura = abs(altura)

print(nueva_base)
print(nueva_altura)
# Out:
# Introduce la base:  -3.0
# Introduce la altura:  -4.0
# 3.0
# 4.0

# %%
base = float(input("Introduce la base: "))
altura = float(input("Introduce la altura: "))
area = base * altura
print("El area del paralelogramo es:", area)
# Out:
# Introduce la base:  3.0
# Introduce la altura:  4.0
# El area del paralelogramo es: 12.0

# %%
nueva_base = abs(base)
nueva_altura = abs(altura)
nueva_area = replace.area [(base, nueva_base), (altura, nueva_altura)]
print(nueva_base, nueva_altura, nueva_area)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 nueva_base = abs(base)
#       2 nueva_altura = abs(altura)
# ----> 3 nueva_area = replace.area [(base, nueva_base), (altura, nueva_altura)]
#       4 print(nueva_base, nueva_altura, nueva_area)
#
# NameError: name 'replace' is not defined

# %%
del base
del altura
del nueva_base
del nueva_altura

# %%
nombre = input("¿Cuál es tu nombre?: ").strip()
edad = input("¿Cuál es tu edad?: ").strip()
año_actual = 2026
año_nacimiento = año_actual - edad

print(f"{nombre}, naciste en el año {año_nacimiento}.")
# Out:
# ¿Cuál es tu nombre?:  Beatriz
# ¿Cuál es tu edad?:  45
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 edad = input("¿Cuál es tu edad?: ").strip()
#       3 año_actual = 2026
# ----> 4 año_nacimiento = año_actual - edad
#       6 print(f"{nombre}, naciste en el año {año_nacimiento}.")
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
año_nacimiento = año_actual - strip(edad)
print(año_nacimiento)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 año_nacimiento = año_actual - strip(edad)
#       2 print(año_nacimiento)
#
# NameError: name 'strip' is not defined

# %%
edad = int(input("¿Cuál es tu edad?: ").strip())
año_actual = 2026
año_nacimiento = año_actual - edad
print(año_nacimiento)
# Out:
# ¿Cuál es tu edad?:  45
# 1981

# %%
print(f"{nombre}, naciste en el año {año_nacimiento}.")
# Out:
# Beatriz, naciste en el año 1981.

# %%
base = decimal(input("si la base es: "))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 base = decimal(input("si la base es: "))
#
# NameError: name 'decimal' is not defined

# %%
base = float(input("Si la base es: "))
altura = float(input("y la altura es: "))
print(f"El área del paralelogramo es: {base*altura}")
# Out:
# Si la base es:  5.5
# y la altura es:  4.7
# El área del paralelogramo es: 25.85

# %%
from decimal import Decimal, ROUND_HALF_UP
def to_two_decimals(num):
    return Decimal(num).quantize(Decimal('0.00'))

nueva_base = print(to_two_decimals(base))
nueva_altura = print(to_two_decimals(altura))
print(f"El área del paralelogramo es: {nueva_base * nueva_altura}")
# Out:
# 5.50
# 4.70
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 7
#       5 nueva_base = print(to_two_decimals(base))
#       6 nueva_altura = print(to_two_decimals(altura))
# ----> 7 print(f"El área del paralelogramo es: {nueva_base * nueva_altura}")
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'NoneType'

# %%
from decimal import Decimal
def dos_decimales(num):
    return Decimal(num).quantize(Decimal('0.00'))

nueva_base = base.replace(float(input("Si la base es: ")), dos_decimales(base)(input("Si la base es: "))
# Out:
#   Cell In[27], line 5
#     nueva_base = base.replace(float(input("Si la base es: ")), dos_decimales(base)(input("Si la base es: "))
#                                                                                                             ^
# SyntaxError: incomplete input

# %%
A = 4
B = "Text"
C = 4.1

A == B
Not A == Not C
A > C
C <= A
B == Not C
# Out:
#   Cell In[28], line 6
#     Not A == Not C
#         ^
# SyntaxError: invalid syntax

# %%
A = 4
B = "Text"
C = 4.1

# %%
A == B
# Out:
# False

# %%
A != C
# Out:
# True

# %%
A > C
# Out:
# False

# %%
base = float(input("Introduce la base: ").strip()
altura = float(input("Introduce la altura: ").strip()
base == altura
# Out:
#   Cell In[34], line 1
#     base = float(input("Introduce la base: ").strip()
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
base = float (input("Introduce la base: ").strip())
altura = float (input("Introduce la altura: ").strip())
base == altura
# Out:
# Introduce la base:  3.5
# Introduce la altura:  5.5
# False

# %%
lado = float (input("Introduce el lado: ").strip())
base == altura == lado
base == altura != lado or base != altura == lado
# Out:
# Introduce el lado:  7.5
# False

# %%
[4, 6, 8, -1]
# Out:
# [4, 6, 8, -1]

# %%
max[4, 6, 8, -1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 max[4, 6, 8, -1]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
max(4, 6, 8, -1)
# Out:
# 8

# %%
sum(4, 6, 8, -1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 sum(4, 6, 8, -1)
#
# TypeError: sum() takes at most 2 arguments (4 given)

# %%
sum[4, 6, 8, -1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sum[4, 6, 8, -1]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
numeros = [4, 6, 8, -1]
total = sum(numeros)

# %%
print(total)
# Out:
# 17

# %%
num_float = 63.451256965
redondeado = (round, 3)

# %%
redondeado
# Out:
# (<function round(number, ndigits=None)>, 3)

# %%
redondeado = round (63.45126965, 3)

# %%
print(redondeado)
# Out:
# 63.451

# %%
num_real = -74
print(abs(num_real))
# Out:
# 74

# %%
frase = "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."

# %%
str.upper(frase)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 str.upper(frase)
#
# TypeError: str.upper() takes no arguments (1 given)

# %%
texto = "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."

# %%
str.upper(texto)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 str.upper(texto)
#
# TypeError: str.upper() takes no arguments (1 given)
