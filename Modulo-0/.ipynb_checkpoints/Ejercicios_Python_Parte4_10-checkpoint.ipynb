# %%
# Ejercicio 1
num_ent = 7
num_real = 13.5
print(type(num_ent))
print(type(num_real))
suma = num_ent + num_real
print(suma)
print(type(suma))
del num_ent
del num_real
# Out:
# <class 'int'>
# <class 'float'>
# 20.5
# <class 'float'>

# %%
print(num_ent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(num_ent)
#
# NameError: name 'num_ent' is not defined

# %%
# Ejercicio 2
import math
grados = str(input())
radianes = float(grados) * float(math.pi/180)
print(radianes)
# Out:
#  93.5
# 1.631882850614698

# %%
# Ejercicio 4
base = str(input("Base:"))
altura = str(input("Altura: "))
area = float(base) * float(altura)
print(area)
# Out:
# Base: 75.5
# Altura:  30
# 2265.0

# %%
# Ejercicio 3
base = int(input("Base: "))
altura = int(input("Altura: "))
area = base * altura
print(area)
# Out:
# Base:  8
# Altura:  9
# 72

# %%
# Ejercicio 5
nombre = input("¿Cuál es tu nombre: ")
edad = int(input("¿Cuál es tu edad: "))
año_actual = 2026
año_nacimiento = año_actual - edad

print(f"{nombre}, naciste el año {año_nacimiento}.")
# Out:
# ¿Cuál es tu nombre:  Beatriz
# ¿Cuál es tu edad:  45
# Beatriz, naciste el año 1981.
