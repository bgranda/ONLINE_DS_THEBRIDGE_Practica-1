# %%
# Ejercicio 1

lista = [4, 6, 8, -1]
print(max(lista))
num = 63.451256965
print(round(num, 3))
print(abs(-74))
# Out:
# 8
# 63.451
# 74

# %%
# Ejercicio 2
string = "En un lugar de la Mancha, de cuyo nombre no quiero acordarme"

# %%
string.upper()
# Out:
# 'EN UN LUGAR DE LA MANCHA, DE CUYO NOMBRE NO QUIERO ACORDARME'

# %%
string.lower()
# Out:
# 'en un lugar de la mancha, de cuyo nombre no quiero acordarme'

# %%
string.title()
# Out:
# 'En Un Lugar De La Mancha, De Cuyo Nombre No Quiero Acordarme'

# %%
lista = string.split()
print(lista)
# Out:
# ['En', 'un', 'lugar', 'de', 'la', 'Mancha,', 'de', 'cuyo', 'nombre', 'no', 'quiero', 'acordarme']

# %%
string.replace(",", ";")
# Out:
# 'En un lugar de la Mancha; de cuyo nombre no quiero acordarme'

# %%
string.replace("a", "")
# Out:
# 'En un lugr de l Mnch, de cuyo nombre no quiero cordrme'

# %%
# Ejercicio 3

lista = [4, 3, 2]

# %%
lista.append(7)
print(lista)
# Out:
# [4, 3, 2, 7]

# %%
sum(lista)
# Out:
# 16

# %%
lista = [4,3,2,7]
elemento = lista.pop(1)
print(lista)
# Out:
# [4, 2, 7]

# %%
lista = [4, 3, 2, 7]
del lista [1]
print(lista)
# Out:
# [4, 2, 7]

# %%
lista_2 = ["manzana", "pera", "naranja"]
nueva_lista = lista + lista_2
print(nueva_lista)
# Out:
# [4, 2, 7, 'manzana', 'pera', 'naranja']

# %%
lista = [4,2,7]
lista_2 = ["manzana", "pera", "naranja"]
lista.extend(lista_2)

# %%
print(lista)
# Out:
# [4, 2, 7, 'manzana', 'pera', 'naranja']

# %%
lista.sort()
print(lista)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 lista.sort()
#       2 print(lista)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
lista = ["manzana", "pera", "naranja", "papaya", "kiwi"]
lista.sort()
print(lista)
# Out:
# ['kiwi', 'manzana', 'naranja', 'papaya', 'pera']

# %%
lista.sort(reverse = True)
print(lista)
# Out:
# ['pera', 'papaya', 'naranja', 'manzana', 'kiwi']
