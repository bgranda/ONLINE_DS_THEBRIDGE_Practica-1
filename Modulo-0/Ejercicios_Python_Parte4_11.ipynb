# %%
# Ejercicio 1
A = 4
B = "Text"
C = 4.1

# %%
A == B
# Out:
# False

# %%
A != C
# Out:
# True

# %%
A > C
# Out:
# False

# %%
C <= A
# Out:
# False

# %%
B != C
# Out:
# True

# %%
# Ejercicio 2

entrada_1 = str(input("Valor_1: "))
entrada_2 = str(input("Valor_2: "))
entrada_1 == entrada_2
# Out:
# Valor_1:  7
# Valor_2:  13.5
# False

# %%
# Ejercicio 3
entrada_1 = input("Entrada1: ")
entrada_2 = input("Entrada2: ")
entrada_3 = input("Entrada3: ")

print(entrada_1 == entrada_2 == entrada_3)
print(entrada_1 == entrada_2 != entrada_3)
print(entrada_1 != entrada_2 == entrada_3)
# Out:
# Entrada1:  Videojuego
# Entrada2:  Avión
# Entrada3:  13
# False
# False
# False
