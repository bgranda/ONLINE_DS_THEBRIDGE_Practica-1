# %%
libreria = [{'titulo': 'La piramide asesinada', 'autor': 'Christian Jacq', 'idioma original': 'francés', 'agno publicacion': 1993}, {'titulo': 'Cocina para todos', 'autor': 'Karlos Arguiñano', 'idioma original': 'español', 'año publicacion': 2025}, {'titulo': 'Book of the dead', 'autor': 'Patricia Cornwell', 'idioma original': 'inglés', 'año publicacion': 2008}, {'titulo': 'El joyero de la reina', 'autor': 'Nieves Herrero', 'idioma original': 'español', 'año publicacion': 2022}, {'titulo': 'Cry Wolf', 'autor': 'Patricia Briggs', 'idioma original': 'ingles', 'año publicacion': 2009}]

# %%
libreria = [{'titulo': 'La piramide asesinada', 'autor': 'Christian Jacq', 'idioma original': 'francés', 'agno publicacion': 1993}, {'titulo': 'Cocina para todos', 'autor': 'Karlos Arguiñano', 'idioma original': 'español', 'año publicacion': 2025}, {'titulo': 'Book of the dead', 'autor': 'Patricia Cornwell', 'idioma original': 'inglés', 'año publicacion': 2008}, {'titulo': 'El joyero de la reina', 'autor': 'Nieves Herrero', 'idioma original': 'español', 'año publicacion': 2022}, {'titulo': 'Cry Wolf', 'autor': 'Patricia Briggs', 'idioma original': 'ingles', 'año publicacion': 2009}]

def buscar_libro(autor, idioma_original, agno_publicacion, titulo = "ninguno"):

    for libro in libreria:
        if libro['autor'].lower() == autor.lower() and libro['idioma original'].lower() == idioma_original.lower() and libro['agno publicacion'] == agno_publicacion:
            return libro
    else:
        return "Ese no le tengo, ¿mola?"

if __name__ == "__main__":
    print(buscar_libro("christian jacq", "francés", 1993))
    print(buscar_libro("stephen king", "inglés", 1986))
# Out:
# {'titulo': 'La piramide asesinada', 'autor': 'Christian Jacq', 'idioma original': 'francés', 'agno publicacion': 1993}
# Ese no le tengo, ¿mola?

# %%
# Ejercicio 11
# Convierte el programa anterior en una función al que se le pasen como argumentos la librería, posicional, 
# y el título, argumento keyword con valor "ninguno" por defecto.

# %%
libreria = [{'titulo': 'La piramide asesinada', 'autor': 'Christian Jacq', 'idioma original': 'francés', 'agno publicacion': 1993}, {'titulo': 'Cocina para todos', 'autor': 'Karlos Arguiñano', 'idioma original': 'español', 'año publicacion': 2025}, {'titulo': 'Book of the dead', 'autor': 'Patricia Cornwell', 'idioma original': 'inglés', 'año publicacion': 2008}, {'titulo': 'El joyero de la reina', 'autor': 'Nieves Herrero', 'idioma original': 'español', 'año publicacion': 2022}, {'titulo': 'Cry Wolf', 'autor': 'Patricia Briggs', 'idioma original': 'ingles', 'año publicacion': 2009}]

def buscar_libro(*libreria, titulo = "ninguno"):

    for libro in libreria:
        if libro['autor'] and libro['idioma original'] and libro['agno publicacion']:
            return libro
    else:
        return "Ese no le tengo, ¿mola?"

if __name__ == "__main__":
    def buscar_libro(libreria, titulo="ninguno"):
        for libro in libreria:
            if titulo == "ninguno" or libro["titulo"].lower() == titulo.lower():
                return libro
        return "Ese no le tengo, ¿mola?"

    print(buscar_libro(libreria, titulo="La piramide asesinada"))
    print(buscar_libro(libreria, titulo="Stephen King"))
    print(buscar_libro("Stephen King", "inglés", 1986))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 12
#       8     else:
#       9         return "Ese no le tengo, ¿mola?"
#      10
#      11 if __name__ == "__main__":
# ---> 12     print(buscar_libro("Christian Jacq", "francés", 1993))
#      13     print(buscar_libro("Stephen King", "inglés", 1986))
#      14
#
# Cell In[5], line 6, in buscar_libro(titulo, *libreria)
#       3 def buscar_libro(*libreria, titulo = "ninguno"):
#       4
#       5     for libro in libreria:
# ----> 6         if libro['autor'] and libro['idioma original'] and libro['agno publicacion']:
#       7             return libro
#       8     else:
#       9         return "Ese no le tengo, ¿mola?"
#
# TypeError: string indices must be integers, not 'str'
