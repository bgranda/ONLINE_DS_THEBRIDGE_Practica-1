# %%
# Ejercicio 1
pizz_familiar = int(input("Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestras pizzas es de 8,95€ para la familiar o de 9,90 € para la mediana. ¿Cuántas pizzas familiares desea?"))
pizz_mediana = int(input("Estupendo, ¿cuántas pizzas medianas desea?"))
direcc = input('Estupendo, se están preparando pizzas familiares y pizz_mediana pizzas medianas. Dígame su dirección')
total = (8.95 * pizz_familiar) + (9.90 * pizz_mediana)
num_pizzas = pizz_familiar + pizz_mediana
final = print("Le mandaremos las {num_pizzas} pizzas a la dirección {direcc}. Serán {total} euros. Muchas gracias por su pedido.")
# Out:
# Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestras pizzas es de 8,95€ para la familiar o de 9,90 € para la mediana. ¿Cuántas pizzas familiares desea? 4
# Estupendo, ¿cuántas pizzas medianas desea? 5
# Estupendo, se están preparando, {pizz_familiar}, pizzas familiares y, {pizz_mediana} pizzas medianas. Dígame su dirección hjk
# Le mandaremos las {num_pizzas} pizzas a la dirección {direcc}. Serán {total} euros. Muchas gracias por su pedido.

# %%
pizz_familiar = int(input("Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestras pizzas es de 8,95€ para la familiar o de 9,90 € para la mediana. ¿Cuántas pizzas familiares desea?"))
pizz_mediana = int(input("Estupendo, ¿cuántas pizzas medianas desea?"))
direcc = input("Estupendo, se están preparando " + pizz_familiar + " pizzas familiares y " + pizz_mediana + " pizzas medianas. Dígame su dirección")
total = (8.95 + pizz_familiar) + (9.90 * pizz_mediana)
num_pizzas = pizz_familiar + pizz_mediana
final = print("Le mandaremos las ", num_pizzas, " pizzas a la dirección ", direcc, ". Serán ", total, "euros. Muchas gracias por su pedido")
# Out:
# Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestras pizzas es de 8,95€ para la familiar o de 9,90 € para la mediana. ¿Cuántas pizzas familiares desea? 4
# Estupendo, ¿cuántas pizzas medianas desea? 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 pizz_familiar = int(input("Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestras pizzas es de 8,95€ para la familiar o de 9,90 € para la mediana. ¿Cuántas pizzas familiares desea?"))
#       2 pizz_mediana = int(input("Estupendo, ¿cuántas pizzas medianas desea?"))
# ----> 3 direcc = input("Estupendo, se están preparando " + pizz_familiar + " pizzas familiares y " + pizz_mediana + " pizzas medianas. Dígame su dirección")
#       4 total = (8.95 + pizz_familiar) + (9.90 * pizz_mediana)
#       5 num_pizzas = pizz_familiar + pizz_mediana
#
# ...
