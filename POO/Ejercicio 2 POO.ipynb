# %%
class Perro:
    
    def __init__(self, raza = "mestizo", pelo = "marron", dueño = "no", patas = 4, orejas = 2, ojos = 2, velocidad = 0):
        self.patas = patas
        self.orejas = orejas
        self.ojos = ojos
        self.velocidad = velocidad
        self.raza = raza
        self.pelo = pelo
        self.dueno = dueño

    def caracteristicas(self):
        print("Raza:", self.raza)
        print("Pelo:", self.pelo)
        print("Dueño:", self.dueno)
        print("Patas:", str(self.patas))
        print("Orejas:", str(self.orejas))
        print("Ojos:", str(self.ojos))
        print("Velocidad:", str(self.velocidad))

# %%
labrador = Perro("Labrador", "Dorado")
labrador.caracteristicas()
# Out:
# Raza: Labrador
# Pelo: Dorado
# Dueño: no
# Patas: 4
# Orejas: 2
# Ojos: 2
# Velocidad: 0

# %%
class Perro:
    
    def __init__(self, raza = "mestizo", pelo = "marron", dueño = "no", patas = 4, orejas = 2, ojos = 2, velocidad = 0, andar = "No", parar = "No", ladrar = "No"):
        self.patas = patas
        self.orejas = orejas
        self.ojos = ojos
        self.velocidad = velocidad
        self.raza = raza
        self.pelo = pelo
        self.dueno = dueño
        self.anda = andar
        self.para = parar
        self.ladra = ladrar

    def caracteristicas(self):
        print("Raza:", self.raza)
        print("Pelo:", self.pelo)
        print("Dueño:", self.dueno)
        print("Patas:", str(self.patas))
        print("Orejas:", str(self.orejas))
        print("Ojos:", str(self.ojos))
        print("Velocidad:", str(self.velocidad))

    def andar(self, andar):
        if velocidad > 0:
            return "El perro está andando"

    def parar(self, parar):
        if self.andar and velocidad == 0:
            return "El perro se para"

    def ladrar(self, ladrar):
        if ladrar == "Sí":
            return "GUAU!"

# %%
labrador = Perro("Labrador", "Dorado", "Sí", "Sí", "Sí")
labrador.caracteristicas()

print(labrador.andar("Sí"))

print(labrador.parar("Sí"))

print(labrador.ladrar("Sí"))
# Out:
# Raza: Labrador
# Pelo: Dorado
# Dueño: Sí
# Patas: Sí
# Orejas: Sí
# Ojos: 2
# Velocidad: 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 labrador = Perro("Labrador", "Dorado", "Sí", "Sí", "Sí")
#       2 labrador.caracteristicas()
# ----> 4 print(labrador.andar("Sí"))
#       6 print(labrador.parar("Sí"))
#       8 print(labrador.ladrar("Sí"))
#
# Cell In[1], line 25, in Perro.andar(self, andar)
#      24 def andar(self, andar):
# ---> 25     if velocidad > 0:
#      26         return "El perro está andando"
#
# NameError: name 'velocidad' is not defined
